# %%
"""Логирование уроков."""

# %% [markdown]
# 06.10.2024
#
# 1. На диаграмме Эйлера-Венна изучили числовые множества:
#     1.1. Натуральные числа;
#     1.2. Целые числа;
#     1.3. Рациональные числа;
#     1.4. Действительные числа;
#     1.5. Комплексные числа.
# 2. Изучили операции над множествами:
#     2.1. Объединение множеств;
#     2.2. Пересечение множеств;
#     2.3. Разность множеств;
#     2.4. Симметрическая разность множеств.

# %% [markdown]
# 07.10.2024
#
# Математический анализ. Введение в интегральное и дифференциальное исчисление. Функция одной переменной.
#
# Доказали в два этапа равенство 1^2 + 2^2 + ... + n^2 = (n(n+1)(2n+1))/6
# Первый этап - база (при n = 1, n = 2, ...)
# Второй этап - индукционный переход (допустили, что верно при n = k + 1).
#
# Параллельно с этим вспомнили формулы дискриминанта и корней уравнения, а также формулу разложения квадратного трехчлена на множители.
